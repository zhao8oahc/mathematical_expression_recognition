# %%
import data

num_char = data.df_label
for character in data.characters: 
    num_char[character] = 0

for row in num_char.iterrows():
    print(row.value[char] for char in data.characters)
#    for character in data.characters:
#        char[character] = file.count(character) 
#for character in data.characters: 
#    num_char[character] = num_char["label"].count(character)

num_char.head()
# Out:
# filename
# train/0.jpg          (0+0)+9=9
# train/1.jpg           9*8+6=78
# train/2.jpg            1+7+0=8
# train/3.jpg           5+4+9=18
# train/4.jpg          7-(1*7)=0
# train/5.jpg            4-1+0=3
# train/6.jpg          (0*7)+0=0
# train/7.jpg        (2*8)*8=128
# train/8.jpg         (4+9)*4=52
# train/9.jpg           3+8+8=19
# train/10.jpg         (6+2)+0=8
# train/11.jpg        (1*4)-8=-4
# train/12.jpg         1-(0-8)=9
# train/13.jpg        6+(7*2)=20
# train/14.jpg          1+7*3=22
# train/15.jpg        (7+2)+2=11
# train/16.jpg           6*1-6=0
# train/17.jpg       (6*3)*8=144
# train/18.jpg        (6+5)*5=55
# train/19.jpg        2-(8+0)=-6
# train/20.jpg         (4-5)+9=8
# train/21.jpg          8+9+8=25
# train/22.jpg         4-6*5=-26
# train/23.jpg        7-(8+7)=-8
# train/24.jpg        3*(1+9)=30
# train/25.jpg          5*9-4=41
# train/26.jpg        (7*8)+3=59
# train/27.jpg        (0*3)-2=-2
# train/28.jpg         (9-5)*0=0
# ...
